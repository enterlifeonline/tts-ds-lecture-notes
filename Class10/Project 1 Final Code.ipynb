# %% [markdown]
# # Final Code

# %%
import requests
from bs4 import BeautifulSoup


URL = "https://www.monster.com/jobs/search/?q=Software-Developer\
        &where=Dallas"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")
results = soup.find(id="ResultsContainer")

# Look for Python jobs
python_jobs = results.find_all("h2", string=lambda t: "python" in t.lower())
for p_job in python_jobs:
    link = p_job.find("a")["href"]
    print(p_job.text.strip())
    print(f"Apply here: {link}\n")

# Print out all available jobs from the scraped webpage
job_elems = results.find_all("section", class_="card-content")
for job_elem in job_elems:
    title_elem = job_elem.find("h2", class_="title")
    company_elem = job_elem.find("div", class_="company")
    location_elem = job_elem.find("div", class_="location")
    if None in (title_elem, company_elem, location_elem):
        continue
    print(title_elem.text.strip())
    print(company_elem.text.strip())
    print(location_elem.text.strip())
    print()
# Out:
# Python Developer/Architect
# Apply here: https://job-openings.monster.com/python-developer-architect-irving-tx-us-synechron/221788290
#
# Human Resources Analytics Developer
# CHRISTUS Health
# Irving, TX
#
# Android Developer (100% Remote) (W2 Only)
# TEKsystems
# Dallas, TX
#
# LEAD SOFTWARE ENGINEER
# IT Echelon Corporation
# Dallas, TX
#
# Cloud Engineer - Dallas
# IBM
# Dallas, TX
#
# Java Microservices Developer
# Mindlance Inc
# Irving, TX
#
# Full Stack Developer
# PowerFusionMedia
# Dallas, TX
#
# Senior Web Developer - (Seattle/Remote Possible)
# CyberCoders
# Dallas, TX
#
# Software Engineers
# Trellis IT Inc
# Farmers Branch, TX
#
# Java Developer
# SMV SOFT
# Dallas, TX
#
# Software Developer IV
# Cottonwood Financial
# Irving, TX
#
# Junior PHP developer
# StaffWizard
#
#
# Software Engineers
# OrangePeople
# Plano, TX
#
# .NET Developer
# Emory Technologies INC
# Coppell, TX
#
# Digital Software Engineer Lead Analyst
# Citicorp Credit Services, Inc. (USA)
# Irving, TX
#
# .Net Developer  (AGND20)
# Attune Global, Inc.
# Coppell, TX
#
# Principal Software Engineers (Level 4)
# STS Technical Services
# Dallas, TX
#
# Lead C#.Net Developer
# K Square Solutions Inc
# Dallas, TX
#
# Looking for FTE Role - AWS terraform Developer - Dallas, TX Experience in Terraform automation / orc
# Global IT Family Inc
# Wilmer, TX
#
# Python Developer/Architect
# Synechron
# Irving, TX
#
# Senior Application Developer
# Macrosoft Inc.
# Dallas, TX
#
# Senior DevOps Developer/Engineer
# Amba Systems
# Plano, TX
#
# Software Developer Training Program - .NET - TX
# Genesis10
# Dallas, TX
#
# JAVA Developer (Middleware/Back End Skills) - Plano, TX
# MindQuest Technology Solutions LLC
# Plano, TX
#
# DevOps Developer
# Peterson Technology Partners, Inc.
# Irving, TX
#
# C# Xamarin Developer
# Lorven Technologies
# Plano, TX
#
# Senior Java Developer
# CCA Professional Recruiting
# Irving, TX
